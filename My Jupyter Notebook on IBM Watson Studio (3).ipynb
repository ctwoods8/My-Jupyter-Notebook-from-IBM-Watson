# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio #

# %% [markdown]
# <b>Cassie Fulton</b>
# <br>Data Scientist</br>

# %% [markdown]
# *I am interested in Data Science because of the pattern I see in everyday life. Through the language we use and the changes in language and how we use it today. I'm also interested in psychology and how the human mind works*

# %% [markdown]
# <h3> Code in cell 5 is supposed to have an input that will be excuted with an output on the next line </h3>

# %%
1+4
# Out:
# 5

# %% [markdown]
# <br>
# <table>
#     <tr>
#         <th> Names</th>
#         <th> Hobbies </th>
#         <th> Age </th>
#     </tr>
#     <tr>
#         <td> Cassie </td>
#         <td>
#     <ul>
#     <li><a href="https://www.google.com/imgres?imgurl=https%3A%2F%2Ftheneonteaparty.com%2Fwp-content%2Fuploads%2F2022%2F03%2FHow-to-Crochet-with-Multiple-Strands-of-Yarn-1-scaled.jpg&imgrefurl=https%3A%2F%2Ftheneonteaparty.com%2F2022%2F03%2F11%2Fhow-to-crochet-with-multiple-strands-of-yarn%2F&tbnid=TFls7V7vWNongM&vet=12ahUKEwiq1qz-jbP7AhUfpo4IHVQvBt4QMygMegUIARCBAg..i&docid=QktqMtF9M3rLfM&w=2048&h=2560&q=crocheting&ved=2ahUKEwiq1qz-jbP7AhUfpo4IHVQvBt4QMygMegUIARCBAg">crocheting</a></li>
#     <li><a href="https://www.google.com/imgres?imgurl=https%3A%2F%2Fwww.artnews.com%2Fwp-content%2Fuploads%2F2020%2F06%2Fshutterstock_147651662.jpg&imgrefurl=https%3A%2F%2Fwww.artnews.com%2Fart-news%2Fproduct-recommendations%2Fbest-how-to-sew-books-1202690817%2F&tbnid=EPGj2_FWcScyWM&vet=12ahUKEwjowpfijrP7AhVQko4IHTfiCroQMygBegUIARDlAQ..i&docid=3Y2GvBO8UyMarM&w=2000&h=1328&q=sewing&ved=2ahUKEwjowpfijrP7AhVQko4IHTfiCroQMygBegUIARDlAQ">sewing</a></li>
#     <li><a href="https://www.google.com/imgres?imgurl=https%3A%2F%2Fcdn.thewirecutter.com%2Fwp-content%2Fmedia%2F2021%2F07%2Fboardgames-2048px-2233.jpg&imgrefurl=https%3A%2F%2Fwww.nytimes.com%2Fwirecutter%2Freviews%2Fboard-games-we-love%2F&tbnid=xAC0f2Dhsm2j8M&vet=12ahUKEwjY67yEj7P7AhW7kI4IHRVfBIYQMygLegUIARD8AQ..i&docid=f4IG5tpJlBA2PM&w=2048&h=1365&q=board%20games&ved=2ahUKEwjY67yEj7P7AhW7kI4IHRVfBIYQMygLegUIARD8AQ">board games</a></li>
#     </ul>
#         </td>
#         <td> 33</td>
#     </tr>
#     <tr>
#         <td> Andrew </td>
#         <td> <ul>
#             <li> Car Mechanics </li>
#             <li> Video Games </li>
#             <li> Road Trips </li>
#             </ul> </td>
#         <td> 35 </td>
#     </tr>
#     <tr>
#     <td> Daniel </td>
#     <td> <ul>
#         <li> Martial Arts</li>
#         <li> Video Games</li>
#         <li> Playing with Friends </li>
#         </ul> </td>
#     <td> 10 </td>
#     </tr>
#     <tr>
#         <td> Chloe </td>
#         <td> <ul>
#             <li> Coloring and Crafts</li>
#             <li> Hide and Seek </li>
#             <li> Playing tag </li>
#             </ul> </td>
#         <td> 3 </td>
#     </tr>
#     <tr>
#     <td> Astrid </td>
#     <td> <ul>
#         <li> Barking at everything</li>
#         <li> Nonstop licking </li>
#         <li> Chasing the kids </li>
#         </ul> </td>
#         <td> 4</td>
#     </tr>
